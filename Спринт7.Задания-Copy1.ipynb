# %%
import os
os.environ['HADOOP_CONF_DIR'] = '/etc/hadoop/conf'
os.environ['YARN_CONF_DIR'] = '/etc/hadoop/conf'

import findspark
findspark.init()
findspark.find()

import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder \
                    .master("yarn") \
                    .appName("Learning DataFrames") \
                    .getOrCreate()

data = [('2021-01-04', 3744, 63, 322),
        ('2021-01-04', 2434, 21, 382),
        ('2021-01-04', 2434, 32, 159),
        ('2021-01-04', 3744, 32, 159),
        ('2021-01-04', 4342, 32, 159),
        ('2021-01-04', 4342, 12, 259),
        ('2021-01-04', 5677, 12, 259),
        ('2021-01-04', 5677, 23, 499)
]

columns = ['dt', 'user_id', 'product_id', 'purchase_amount']
df = spark.createDataFrame(data=data, schema=columns)
# Out:
# No Java runtime present, requesting install.
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/pyspark/bin/spark-class: line 97: CMD: bad array subscript
# head: illegal line count -- -1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       1 import pyspark
#       2 from pyspark.sql import SparkSession
# ----> 4 spark = SparkSession.builder \
#       5                     .master("local") \
#       6                     .appName("Learning DataFrames") \
#       7                     .getOrCreate()
#       9 data = [('2021-01-04', 3744, 63, 322),
#      10         ('2021-01-04', 2434, 21, 382),
#      11         ('2021-01-04', 2434, 32, 159),
#    (...)
#      16         ('2021-01-04', 5677, 23, 499)
#      17 ]
#      19 columns = ['dt', 'user_id', 'product_id', 'purchase_amount']
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyspark/sql/session.py:477, in SparkSession.Builder.getOrCreate(self)
#     475     sparkConf.set(key, value)
#     476 # This SparkContext may be an existing one.
# --> 477 sc = SparkContext.getOrCreate(sparkConf)
#     478 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     479 # by all sessions.
#     480 session = SparkSession(sc, options=self._options)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyspark/context.py:512, in SparkContext.getOrCreate(cls, conf)
#     510 with SparkContext._lock:
#     511     if SparkContext._active_spark_context is None:
# --> 512         SparkContext(conf=conf or SparkConf())
#     513     assert SparkContext._active_spark_context is not None
#     514     return SparkContext._active_spark_context
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyspark/context.py:198, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     192 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     193     raise ValueError(
#     194         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     195         " is not allowed as it is a security risk."
#     196     )
# --> 198 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     199 try:
#     200     self._do_init(
#     201         master,
#     202         appName,
#    (...)
#     212         memory_profiler_cls,
#     213     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyspark/context.py:432, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     430 with SparkContext._lock:
#     431     if not SparkContext._gateway:
# --> 432         SparkContext._gateway = gateway or launch_gateway(conf)
#     433         SparkContext._jvm = SparkContext._gateway.jvm
#     435     if instance:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyspark/java_gateway.py:106, in launch_gateway(conf, popen_kwargs)
#     103     time.sleep(0.1)
#     105 if not os.path.isfile(conn_info_file):
# --> 106     raise RuntimeError("Java gateway process exited before sending its port number")
#     108 with open(conn_info_file, "rb") as info:
#     109     gateway_port = read_int(info)
#
# RuntimeError: Java gateway process exited before sending its port number

# %%
+-------+---+
|   Name|Age|
+-------+---+
|    Max| 55|
|    Yan| 53|
| Dmitry| 54|
|    Ann| 25|
+-------+---+

# %%
import os
os.environ['HADOOP_CONF_DIR'] = '/etc/hadoop/conf'
os.environ['YARN_CONF_DIR'] = '/etc/hadoop/conf'

import findspark
findspark.init()
findspark.find()

import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder \
                    .master("yarn") \
                    .appName("delendikms_dataframe_task_1") \
                    .getOrCreate()

data = [('Max', 55),
        ('Yan', 53),
        ('Dmitry', 54),
        ('Ann', 25)
]

columns = ['Name', 'Age']
df = spark.createDataFrame(data=data, schema=columns)
df.printSchema()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 5>()
#       2 os.environ['HADOOP_CONF_DIR'] = '/etc/hadoop/conf'
#       3 os.environ['YARN_CONF_DIR'] = '/etc/hadoop/conf'
# ----> 5 import findspark
#       6 findspark.init()
#       7 findspark.find()
#
# ModuleNotFoundError: No module named 'findspark'

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder \
                    .master("yarn") \
                    .appName("delendikms_dataframe_task_2") \
                    .getOrCreate()
usersDF = spark.read.load(path = "/user/master/data/events/date=2022-05-25", format = 'json')

# %%
import os
os.environ['HADOOP_CONF_DIR'] = '/etc/hadoop/conf'
os.environ['YARN_CONF_DIR'] = '/etc/hadoop/conf'

import findspark
findspark.init()
findspark.find()

import pyspark
from pyspark.sql import SparkSession
from pyspark.context import SparkContext
spark = SparkSession \
    .builder \
    .master("yarn") \
        .config("spark.driver.cores", "3") \
        .config("spark.driver.memory", "3g") \
        .appName("Data Lake load") \
        .getOrCreate()
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/lib/spark/jars/slf4j-log4j12-1.7.30.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/usr/lib/hadoop/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# 2023-05-07 10:33:58,925 WARN util.Utils: Your hostname, fhmgda1c2j89rj3nla6s resolves to a loopback address: 127.0.1.1; using 172.16.0.56 instead (on interface eth0)
# 2023-05-07 10:33:58,926 WARN util.Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 2023-05-07 10:34:01,484 WARN util.Utils: spark.executor.instances less than spark.dynamicAllocation.minExecutors is invalid, ignoring its setting, please update your configs.
# 2023-05-07 10:34:21,812 WARN util.Utils: spark.executor.instances less than spark.dynamicAllocation.minExecutors is invalid, ignoring its setting, please update your configs.
# 2023-05-07 10:34:21,825 WARN cluster.YarnSchedulerBackend$YarnSchedulerEndpoint: Attempted to request executors before the AM has registered!

# %%
usersDF = spark.read.load(path = "/user/master/data/events/date=2022-05-25", format = 'json')
usersDF.show(10)

# %%
# !hdfs dfs -ls /user/master/data/snapshots/channels/actual
# Out:
#   Input In [9]
#     hadoop fs -ls /user/master/data/snapshots
#            ^
# SyntaxError: invalid syntax

# %%
df=spark.read.parquet("/user/master/data/snapshots/channels/actual/part-00000-beae86b3-af54-4415-8f29-31dd79cfe178-c000.snappy.parquet")
#df.show()

df.write.option("header",True) \
        .partitionBy("channel_type") \
        .mode("append") \
        .parquet("/user/msdelendik/analytics/test")

df_new = spark.read.parquet("/user/msdelendik/analytics/test")
df_new.select("channel_type").orderBy("channel_type").distinct().show()

#df.write.format('csv').mode('overwrite').save('dataseets/covid19_dataset/time_province_2')

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder \
                    .master("local") \
                    .appName("Learning DataFrames") \
                    .getOrCreate()
# данные первого датафрейма 
book = [('Harry Potter and the Goblet of Fire', 'J. K. Rowling', 322),
        ('Nineteen Eighty-Four', 'George Orwell', 382),
        ('Jane Eyre', 'Charlotte Brontë', 159),
        ('Catch-22', 'Joseph Heller',  174),
        ('The Catcher in the Rye', 'J. D. Salinger',  168),
        ('The Wind in the Willows', 'Kenneth Grahame',  259),
        ('The Mayor of Casterbridge', 'Thomas Hardy',  300),
        ('Bad Girls', 'Jacqueline Wilson',  299)
]
# данные второго датафрейма
library = [
        ( 322, "1"),
        ( 250, "2" ),
        (400, "2"),
        (159, "1"),
        (382, "2"),
        (322, "1")
]
# названия атрибутов
columns = ['title', 'author', 'book_id']
columns_library = ['book_id', 'Library_id']
# создаём датафреймы
df = spark.createDataFrame(data=book, schema=columns)
df_library  = spark.createDataFrame(data=library, schema=columns_library )
# напишите ваш код ниже
df_join =df.join(df_library, ['book_id'], 'anti')
df_join.select('title').distinct().show(10,False)
df_join.distinct().count()

# %% [markdown]
# ## book_1 = [('Harry Potter and the Goblet of Fire', 'J. K. Rowling', 322),
#         ('Nineteen Eighty-Four', 'George Orwell', 382),
#         ('Jane Eyre', 'Charlotte Brontë', 159),
#         ('Catch-22', 'Joseph Heller',  174),
#         ('The Catcher in the Rye', 'J. D. Salinger',  168),
#         ('The Wind in the Willows', 'Kenneth Grahame',  259),
#         ('The Mayor of Casterbridge', 'Thomas Hardy',  300),
#         ('Bad Girls', 'Jacqueline Wilson',  299)
# ]
# # данные второго датафрейма
# book_2 = [
#         ('Black Beauty',657 ,'Anna Sewell'),
#         ('Artemis Fowl',558,'Eoin Colfer'),
#         ('The Magic Faraway Tree', 567,'Enid Blyton'),
#         ('The Witches', 567,'Roald Dahl'),
#         ('Frankenstein',567 ,'Mary Shelley'),
#         ('The Little Prince',557 ,'Antoine de Saint-Exupéry'),
#         ('The Truth', 576 ,'Terry Pratchett')
# ]
# # названия атрибутов
# columns_1= ['title', 'author', 'book_id']
# columns_2 = ['title', 'book_id', 'author']
# # создаём датафреймы
# df_1 = spark.createDataFrame(data=book_1 , schema=columns_1)
# df_2  = spark.createDataFrame(data=book_2 , schema=columns_2)
# # напишите ваш код ниже
# df_1.unionByName(df_2).show(100, False)

# %%
spark.sparkContext.setCheckpointDir("hdfs://rc1a-dataproc-m-dg5lgqqm7jju58f9.mdb.yandexcloud.net//user/msdelendik/analytics/test_check")
df_join.checkpoint()
df_join.explain()

# %%
usersDF = spark.read.load(path = "hdfs://rc1a-dataproc-m-dg5lgqqm7jju58f9.mdb.yandexcloud.net//user/master/data/events/date=2022-05-31", format = 'json')
usersDF.show(10)

# %%
import pyspark.sql.functions as F

usersDF = spark.read.load(path = "hdfs://rc1a-dataproc-m-dg5lgqqm7jju58f9.mdb.yandexcloud.net//user/master/data/events/date=2022-05-31", format = 'JSON')
usersDF.withColumn('hour', F.hour(F.col("event.datetime"))) \
        .withColumn('minute', F.minute(F.col("event.datetime"))) \
        .withColumn('second', F.second(F.col("event.datetime"))) \
        .orderBy(F.col("event.datetime").desc()) \
        .show(10)

# %%
usersDF.filter(F.col("event.message_to").isNotNull()).count()

# %%
max_react_df = spark.read.load(path = "hdfs://rc1a-dataproc-m-dg5lgqqm7jju58f9.mdb.yandexcloud.net//user/master/data/events/date=2022-05-25", format = 'JSON')
#max_react_df.select(F.col("event_type")).distinct().show(10, False)
#max_react_df.select(F.col("event.reaction_type")).distinct().show(10, False)
df_2 = max_react_df.filter(F.col("event_type")=="reaction").groupBy(F.col("event.reaction_from")).count()
df_2.select(F.max("count")).show()

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder \
                    .master("local") \
                    .appName("Learning DataFrames") \
                    .getOrCreate()
# данные  датафрейма 
data = [('2021-01-06', 3744, 63, 322),
        ('2021-01-04', 2434, 21, 382),
        ('2021-01-04', 2434, 32, 159),
        ('2021-01-05', 3744, 32, 159),
        ('2021-01-06', 4342, 32, 159),
        ('2021-01-05', 4342, 12, 259),
        ('2021-01-06', 5677, 12, 259),
        ('2021-01-04', 5677, 23, 499)
]
# названия атрибутов
columns = ['dt', 'user_id', 'product_id', 'purchase_amount']
# создаём датафрейм
df = spark.createDataFrame(data=data, schema=columns)

# %%
# импортируем оконную функцию и модуль Spark Functions
from pyspark.sql.window import Window 
import pyspark.sql.functions as F

# создаём объект оконной функции
window = Window().partitionBy(['dt']).orderBy(F.asc('purchase_amount'))

# создаём колонку с рассчитанной статистикой по оконной функции
df_window = df.withColumn("rank", F.rank().over(window))

# выводим нужные колонки
df_window.select('dt', 'user_id', 'rank', 'purchase_amount').show()

# %%
# создаём объект оконной функции
window_2 = Window().orderBy(F.asc('purchase_amount'))

# создаём колонку с рассчитанной статистикой по оконной функции
df_window = df.withColumn("row_number", F.row_number().over(window_2))

# выводим нужные колонки
df_window.select('dt', 'user_id', 'purchase_amount', 'row_number').show()

# %%
events = spark.read.json("/user/master/data/events/date=2022-05-01")
# Выведите схему датафрейма ниже
events.printSchema()
#events.withColumn("data", F.explode("event")).show()
#events.select(F.col("event")).show()

# %%
window = Window().partitionBy("event.message_from").orderBy('event.user')

dfWithLag = events.withColumn("lag_7",F.lag("event.message_to", 7).over(window))

dfWithLag.select("event.message_from", "lag_7") \
.filter(dfWithLag.lag_7.isNotNull()) \
.orderBy(F.desc("event.message_from")) \
.show(10, False)

# %%
data = [('2021-01-06', 3744, 63, 322),
        ('2021-01-04', 2434, 21, 382),
        ('2021-01-04', 2434, 32, 159),
        ('2021-01-05', 3744, 32, 159),
        ('2021-01-06', 4342, 32, 159),
        ('2021-01-05', 4342, 12, 259),
        ('2021-01-06', 5677, 12, 259),
        ('2021-01-04', 5677, 23, 499)
]

columns = ['dt', 'user_id', 'product_id', 'purchase_amount']

df = spark.createDataFrame(data=data, schema=columns)

window = Window().partitionBy("user_id")

df_min_max = df.withColumn("min", F.min("purchase_amount").over(window)) \
            .withColumn("max", F.max("purchase_amount").over(window))

df_min_max.select("user_id", "max", "min") \
            .distinct() \
            .show()

# %%
events = spark.read.json("/user/master/data/events")
events.write \
        .partitionBy("date", "event_type") \
        .mode("overwrite") \
        .parquet("/user/msdelendik/data/events")

# %%
spark.read.parquet("/user/msdelendik/data/events").orderBy(F.col('event.datetime').desc()).show(10)

# %%
# Импортируем системную библиотеку
import sys

# Объявляем функцию main, которая будет выполнять джобу. 
# Так код будет удобно и правильно оформлен.
def main():
                client_name = sys.argv[1] # параметризуем имя клиента
        date = sys.argv[2] # параметризуем дату
        dir_name = sys.argv[3] # параметризуем директорию

                # Здесь будет основная часть кода
    
if __name__ == "__main__":
        main()

# %%
import sys
 
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
import pyspark.sql.functions as F
 
def main():
        date = sys.argv[1]
        base_input_path = sys.argv[2]
        base_output_path = sys.argv[3]

        conf = SparkConf().setAppName(f"EventsPartitioningJob-{date}")
        sc = SparkContext(conf=conf)
        sql = SQLContext(sc)

 # Напишите директорию чтения в общем виде
        events = sql.read.json(f"{base_input_path}/date={date}")

# Напишите директорию записи
        events\
        .write\
        .partitionBy("event_type") \
        .mode("overwrite") \
        .parquet(f"{base_output_path}/date={date}")


if __name__ == "__main__":
        main()

# %%
from datetime import datetime, date, timedelta
dt = '2023-05-06' 
#dt_1 = datetime.fromisoformat(dt).date() - 8
dt_1 = datetime.strptime(dt, '%Y-%m-%d') - timedelta(days=1)
#dt_1 = datetime.date(dt, '%y/%m/%d') - 8 
print(dt_1)
# Out:
# 2023-05-05 00:00:00

# %%
from datetime import datetime, timedelta

def input_paths (date: str, depth: int):
    path_list = []
    for i in range (depth):
        dt = datetime.strptime(date, '%Y-%m-%d') - timedelta(days=i)
        dt = dt.date()
        path = f"/user/msdelendik/data/events/date={dt}/event_type=message"
        path_list.append(path)
    print(path_list)
#     if depth is not None:
#         path_list.append(path)
#     if depth is None: 
#             raise

input_paths ('2023-05-07', 8)
# Out:
# ['/user/msdelendik/data/events/date=2023-05-07/event_type=message', '/user/msdelendik/data/events/date=2023-05-06/event_type=message', '/user/msdelendik/data/events/date=2023-05-05/event_type=message', '/user/msdelendik/data/events/date=2023-05-04/event_type=message', '/user/msdelendik/data/events/date=2023-05-03/event_type=message', '/user/msdelendik/data/events/date=2023-05-02/event_type=message', '/user/msdelendik/data/events/date=2023-05-01/event_type=message', '/user/msdelendik/data/events/date=2023-04-30/event_type=message']

# %%
# !hdfs dfs -ls "/user/msdelendik/data/events/date=yyyy-MM-dd/event_type=message"
# Out:
# /bin/bash: hdfs: command not found

# %%
import datetime
import pyspark.sql.functions as F

def input_paths(date, depth):
    dt = datetime.datetime.strptime(date, '%Y-%m-%d')
    return [f"/user/msdelendik/data/events/date={(dt-datetime.timedelta(days=x)).strftime('%Y-%m-%d')}/event_type=message" for x in range(depth)]

paths = input_paths('2022-05-31', 7)
messages = spark.read.parquet(*paths)
all_tags = messages.where("event.message_channel_to is not null").selectExpr(["event.message_from as user", "explode(event.tags) as tag"]).groupBy("tag").agg(F.expr("count(distinct user) as suggested_count")).where("suggested_count >= 100")
verified_tags = spark.read.parquet("/user/master/data/snapshots/tags_verified/actual")
candidates = all_tags.join(verified_tags, "tag", "left_anti")

candidates.write.parquet('/user/msdelendik/data/analytics/candidates_d7_pyspark')

# %%
import datetime
import pyspark.sql.functions as F

def input_paths(date, depth):
    dt = datetime.datetime.strptime(date, '%Y-%m-%d')
    return [f"/user/msdelendik/data/events/date={(dt-datetime.timedelta(days=x)).strftime('%Y-%m-%d')}/event_type=message" for x in range(depth)]

paths = input_paths('2022-05-31', 84)
messages = spark.read.parquet(*paths)
all_tags = messages.where("event.message_channel_to is not null").selectExpr(["event.message_from as user", "explode(event.tags) as tag"]).groupBy("tag").agg(F.expr("count(distinct user) as suggested_count")).where("suggested_count >= 100")
verified_tags = spark.read.parquet("/user/master/data/snapshots/tags_verified/actual")
candidates = all_tags.join(verified_tags, "tag", "left_anti")

candidates.write.parquet('/user/msdelendik/data/analytics/candidates_d84_pyspark')

# %%
df=spark.read.parquet('/user/msdelendik/data/analytics/candidates_d7_pyspark')
df.describe().show()
# Out:
# [Stage 18:>                                                         (0 + 1) / 1]
# +-------+--------+------------------+
# |summary|     tag|   suggested_count|
# +-------+--------+------------------+
# |  count|       6|                 6|
# |   mean|    null|176.66666666666666|
# | stddev|    null|127.64899790702106|
# |    min|Finelook|               105|
# |    max|   Чулан|               434|
# +-------+--------+------------------+

# %%
df=spark.read.parquet('/user/msdelendik/data/analytics/candidates_d84_pyspark')
df.describe().show()
# Out:
# [Stage 20:===========================================>              (3 + 1) / 4]
# +-------+---------+------------------+
# |summary|      tag|   suggested_count|
# +-------+---------+------------------+
# |  count|      210|               210|
# |   mean|     null|305.84285714285716|
# | stddev|     null| 439.2009371873509|
# |    min|     *nix|               100|
# |    max|Я пиарюсь|              5440|
# +-------+---------+------------------+

# %%
/usr/lib/spark/bin/spark-submit --master yarn --deploy-mode cluster /lessons/verified_tags_candidates.py 2022-05-31 5 300 /user/msdelendik/data/events /user/master/data/snapshots/tags_verified/actual /user/msdelendik/5.2.4/analytics/verified_tags_candidates_d5
# Out:
#   Cell In[24], line 1
#     usr/lib/spark/bin/spark-submit(--master, yarn, --deploy-mode, cluster, /lessons/verified_tags_candidates.py, 2022-05-31, 5, 300, /user/msdelendik/data/events, /user/master/data/snapshots/tags_verified/actual, /user/msdelendik/5.2.4/analytics/verified_tags_candidates_d5)
#                                                                            ^
# SyntaxError: invalid syntax

# %%
# !hdfs dfs -ls "/user/msdelendik/5.2.4/analytics"
# Out:
# Found 1 items
# drwxr-xr-x   - msdelendik msdelendik          0 2023-05-07 13:16 /user/msdelendik/5.2.4/analytics/verified_tags_candidates_d5

# %%
# !hdfs dfs -ls "/user/msdelendik/5.2.4/analytics/verified_tags_candidates_d5"
# Out:
# ls: `/user/msdelendik/5.2.4/analytics/verified_tags_candidates_d5': No such file or directory

# %%
/user/msdelendik/5.2.4/analytics/verified_tags_candidates_d5

# %%
import datetime
import pyspark.sql.functions as F
from pyspark.sql.window import Window
 
def input_event_paths(date, depth):
    dt = datetime.datetime.strptime(date, '%Y-%m-%d')
    return [f"/user/msdelendik/data/events/date={(dt-datetime.timedelta(days=x)).strftime('%Y-%m-%d')}" for x in range(depth)]
 
def tag_tops(date, depth, spark):
		message_paths = input_event_paths(date, depth)
		result = spark.read\
    .option("basePath", "/user/msdelendik/data/events")\
    .parquet(*message_paths)\
    .where("event_type = 'message'")\
		.where("event.message_channel_to is not null")\
		.select(F.col("event.message_id").alias("message_id"),
		        F.col("event.message_from").alias("user_id"),
		        F.explode(F.col("event.tags")).alias("tag"))\
		.groupBy("user_id", "tag")\
		.agg(F.count("*").alias("tag_count"))\
		.withColumn("rank", F.row_number().over(Window.partitionBy("user_id")\
        .orderBy(F.desc("tag_count"), F.desc("tag"))))\
		.where("rank <= 3")\
		.groupBy("user_id")\
		.pivot("rank", [1, 2, 3])\
		.agg(F.first("tag"))\
		.withColumnRenamed("1", "tag_top_1")\
		.withColumnRenamed("2", "tag_top_2")\
		.withColumnRenamed("3", "tag_top_3")
 
		return result

tag_tops('2022-05-04', 1, spark).repartition(1).write.parquet('/user/msdelendik/data/tmp/tag_tops_05_04_1')
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[42], line 33
#      11 		result = spark.read\
#      12     .option("basePath", "/user/msdelendik/data/events")\
#      13     .parquet(*message_paths)\
#    (...)
#      28 		.withColumnRenamed("2", "tag_top_2")\
#      29 		.withColumnRenamed("3", "tag_top_3")
#      31 		return result
# ---> 33 tag_tops('2022-05-04', 1, spark).repartition(1).write.parquet('/user/msdelendik/data/tmp/tag_tops_05_04_1')
#
# File /usr/lib/spark/python/pyspark/sql/readwriter.py:939, in DataFrameWriter.parquet(self, path, mode, partitionBy, compression)
#     937     self.partitionBy(partitionBy)
#     938 self._set_opts(compression=compression)
# --> 939 self._jwrite.parquet(path)
#
# File /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py:1304, in JavaMember.__call__(self, *args)
#    1298 command = proto.CALL_COMMAND_NAME +\
#    1299     self.command_header +\
#    1300     args_command +\
#    1301     proto.END_COMMAND_PART
#    1303 answer = self.gateway_client.send_command(command)
# -> 1304 return_value = get_return_value(
#    1305     answer, self.gateway_client, self.target_id, self.name)
#    1307 for temp_arg in temp_args:
#    1308     temp_arg._detach()
#
# File /usr/lib/spark/python/pyspark/sql/utils.py:134, in capture_sql_exception.<locals>.deco(*a, **kw)
#     130 converted = convert_exception(e.java_exception)
#     131 if not isinstance(converted, UnknownException):
#     132     # Hide where the exception came from that shows a non-Pythonic
#     133     # JVM exception message.
# --> 134     raise_from(converted)
#     135 else:
#     136     raise
#
# File <string>:3, in raise_from(e)
#
# AnalysisException: path hdfs://rc1a-dataproc-m-dg5lgqqm7jju58f9.mdb.yandexcloud.net/user/msdelendik/data/tmp/tag_tops_05_04_1 already exists.;

# %%
import datetime
import pyspark.sql.functions as F
from pyspark.sql.window import Window
 
def input_event_paths(date, depth):
    dt = datetime.datetime.strptime(date, '%Y-%m-%d')
    return [f"/user/msdelendik/data/events/date={(dt-datetime.timedelta(days=x)).strftime('%Y-%m-%d')}" for x in range(depth)]
 
def reaction_tag_tops(date, depth, spark):
		reaction_paths = input_event_paths(date, depth)
		reactions = spark.read\
    .option("basePath", "/user/msdelendik/data/events")\
    .parquet(*reaction_paths)\
    .where("event_type='reaction'")
 
		all_message_tags = spark.read.parquet("/user/msdelendik/data/events")\
		.where("event_type='message' and event.message_channel_to is not null")\
		.select(F.col("event.message_id").alias("message_id"),
		        F.col("event.message_from").alias("user_id"),
		        F.explode(F.col("event.tags")).alias("tag")
		)
 
		reaction_tags = reactions\
		.select(F.col("event.reaction_from").alias("user_id"), 
		        F.col("event.message_id").alias("message_id"), 
		        F.col("event.reaction_type").alias("reaction_type")
		).join(all_message_tags.select("message_id", "tag"), "message_id")
 
		reaction_tops = reaction_tags\
		.groupBy("user_id", "tag", "reaction_type")\
		.agg(F.count("*").alias("tag_count"))\
		.withColumn("rank", F.row_number().over(Window.partitionBy("user_id", "reaction_type")\
        .orderBy(F.desc("tag_count"), F.desc("tag"))))\
		.where("rank <= 3")\
		.groupBy("user_id", "reaction_type")\
		.pivot("rank", [1, 2, 3])\
		.agg(F.first("tag"))\
		.cache()
 
		like_tops = reaction_tops\
		.where("reaction_type = 'like'")\
		.drop("reaction_type")\
		.withColumnRenamed("1", "like_tag_top_1")\
		.withColumnRenamed("2", "like_tag_top_2")\
		.withColumnRenamed("3", "like_tag_top_3")
 
		dislike_tops = reaction_tops\
		.where("reaction_type = 'dislike'")\
		.drop("reaction_type")\
		.withColumnRenamed("1", "dislike_tag_top_1")\
		.withColumnRenamed("2", "dislike_tag_top_2")\
		.withColumnRenamed("3", "dislike_tag_top_3")
 
		result = like_tops\
		.join(dislike_tops, "user_id", "full_outer")
 
		return result

reaction_tag_tops('2022-04-04', 1, spark).write.parquet('/user/msdelendik/data/tmp/reaction_tag_tops_04_04_1')
# Out:
# 2023-05-07 14:19:55,961 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_158 !
# 2023-05-07 14:19:55,961 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_135 !
# 2023-05-07 14:19:55,961 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_20 !
# 2023-05-07 14:19:55,961 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_1 !
# 2023-05-07 14:19:55,961 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_55 !
# 2023-05-07 14:19:55,961 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_106 !
# 2023-05-07 14:19:55,961 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_111 !
# 2023-05-07 14:19:55,961 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_198 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_166 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_70 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_84 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_48 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_24 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_0 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_32 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_16 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_41 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_144 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_142 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_59 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_183 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_118 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_81 !
# 2023-05-07 14:19:55,962 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_129 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_174 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_65 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_81 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_186 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_50 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_21 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_127 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_140 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_193 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_99 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_190 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_99 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_126 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_183 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_16 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_24 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_33 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_136 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_154 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_190 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_7 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_28 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_96 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_90 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_37 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_197 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_178 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_154 !
# 2023-05-07 14:19:55,963 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_194 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_105 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_123 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_28 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_46 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_186 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_77 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_61 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_114 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_93 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_58 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_54 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_87 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_122 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_171 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_163 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_103 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_165 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_112 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_12 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_176 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_45 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_145 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_43 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_139 !
# 2023-05-07 14:19:55,964 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_73 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_116 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_92 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_78 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_36 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_8 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_149 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_109 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_172 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_69 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_74 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_61 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_39 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_52 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_65 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_11 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_131 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_149 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_180 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_88 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_157 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_119 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_102 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_133 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_169 !
# 2023-05-07 14:19:55,965 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_161 !
# 2023-05-07 14:20:05,370 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_140 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_94 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_155 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_34 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_104 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_144 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_77 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_194 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_57 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_58 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_175 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_3 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_106 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_11 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_189 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_104 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_49 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_170 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_17 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_23 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_75 !
# 2023-05-07 14:20:05,371 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_119 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_157 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_29 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_12 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_51 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_2 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_93 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_120 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_82 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_133 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_151 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_22 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_9 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_67 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_146 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_115 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_84 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_113 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_4 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_38 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_62 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_88 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_192 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_56 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_178 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_148 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_92 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_45 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_174 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_119 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_8 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_100 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_98 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_73 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_115 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_129 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_172 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_94 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_1 !
# 2023-05-07 14:20:05,372 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_172 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_26 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_79 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_34 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_3 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_46 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_164 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_141 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_36 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_90 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_186 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_132 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_177 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_14 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_69 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_77 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_76 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_150 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_168 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_196 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_67 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_170 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_13 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_27 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_177 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_30 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_35 !
# 2023-05-07 14:20:05,373 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_86 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_191 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_28 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_43 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_179 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_62 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_110 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_198 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_181 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_9 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_160 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_56 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_114 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_89 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_143 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_164 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_104 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_31 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_31 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_190 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_70 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_188 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_118 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_52 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_5 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_83 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_30 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_59 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_27 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_7 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_66 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_195 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_72 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_108 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_49 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_20 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_181 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_47 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_153 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_66 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_192 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_136 !
# 2023-05-07 14:20:05,374 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_168 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_107 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_23 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_182 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_175 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_170 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_61 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_70 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_26 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_163 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_103 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_166 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_199 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_152 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_185 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_91 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_54 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_152 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_88 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_96 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_181 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_73 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_39 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_135 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_160 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_125 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_137 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_130 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_132 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_53 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_67 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_164 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_173 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_127 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_158 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_60 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_187 !
# 2023-05-07 14:20:05,375 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_160 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_92 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_199 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_123 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_111 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_137 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_143 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_197 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_140 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_78 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_101 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_147 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_49 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_148 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_110 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_161 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_36 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_122 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_85 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_162 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_35 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_44 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_6 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_45 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_20 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_179 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_5 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_108 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_100 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_188 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_95 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_113 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_3 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_128 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_40 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_158 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_125 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_151 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_155 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_15 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_75 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_97 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_47 !
# 2023-05-07 14:20:05,376 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_71 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_51 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_11 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_125 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_130 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_198 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_18 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_54 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_147 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_22 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_18 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_123 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_87 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_57 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_15 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_15 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_10 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_138 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_5 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_24 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_25 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_13 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_39 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_128 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_64 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_63 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_183 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_121 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_42 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_80 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_120 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_117 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_196 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_40 !
# 2023-05-07 14:20:05,377 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_42 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_83 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_102 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_4 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_80 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_193 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_32 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_98 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_167 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_185 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_141 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_116 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_19 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_107 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_138 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_85 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_145 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_155 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_63 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_134 !
# 2023-05-07 14:20:05,378 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_1 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_157 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_0 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_37 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_68 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_18 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_152 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_109 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_37 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_176 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_124 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_79 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_138 !
# 2023-05-07 14:20:05,517 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_154 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_112 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_44 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_95 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_180 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_17 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_188 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_33 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_93 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_85 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_166 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_105 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_159 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_99 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_75 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_29 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_14 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_173 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_113 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_173 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_6 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_48 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_121 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_102 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_167 !
# 2023-05-07 14:20:05,518 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_109 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_57 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_189 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_161 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_41 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_25 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_156 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_191 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_79 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_193 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_71 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_33 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_142 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_149 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_91 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_195 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_96 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_180 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_48 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_21 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_176 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_64 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_25 !
# 2023-05-07 14:20:05,519 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_142 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_60 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_139 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_21 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_52 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_163 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_44 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_84 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_101 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_131 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_29 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_130 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_8 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_105 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_128 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_146 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_68 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_122 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_41 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_135 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_169 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_9 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_97 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_90 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_168 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_184 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_2 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_72 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_146 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_12 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_185 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_82 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_126 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_117 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_87 !
# 2023-05-07 14:20:05,520 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_55 !
# 2023-05-07 14:20:05,521 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_116 !
# 2023-05-07 14:20:05,521 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_134 !
# 2023-05-07 14:20:05,521 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_51 !
# 2023-05-07 14:20:05,521 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_150 !
# 2023-05-07 14:20:05,521 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_76 !
# 2023-05-07 14:20:05,521 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_196 !
# 2023-05-07 14:20:05,521 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_64 !
# 2023-05-07 14:20:05,521 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_60 !

# %%
df = spark.read.parquet('/user/msdelendik/data/tmp/reaction_tag_tops_04_04_1')
df.select('*').show(10, False)
# Out:
# [Stage 74:>                                                         (0 + 1) / 1]
# +-------+-------------------------------+----------------+-------------------+-----------------+-----------------------------+-----------------+
# |user_id|like_tag_top_1                 |like_tag_top_2  |like_tag_top_3     |dislike_tag_top_1|dislike_tag_top_2            |dislike_tag_top_3|
# +-------+-------------------------------+----------------+-------------------+-----------------+-----------------------------+-----------------+
# |100138 |pldt                           |pavelcurda      |pave-curda         |null             |null                         |null             |
# |10076  |null                           |null            |null               |Я пиарюсь        |steelbrick                   |quote-to-cash    |
# |100950 |vkontakte-ru                   |vk-com          |stripe             |null             |null                         |null             |
# |10116  |Функциональное программирование|Программирование|style              |null             |null                         |null             |
# |101277 |Разработка веб-сайтов          |Криптография    |Компьютерное железо|null             |null                         |null             |
# |101665 |y-combinator                   |postcards       |photo-sharing      |null             |null                         |null             |
# |101783 |null                           |null            |null               |Чулан            |voip                         |social-news      |
# |102020 |null                           |null            |null               |Научно-популярное|Космонавтика                 |startups         |
# |10214  |Децентрализованные сети        |null            |null               |Разработка игр   |Ненормальное программирование|null             |
# |102372 |null                           |null            |null               |yammer           |salesforce-com               |prisma           |
# +-------+-------------------------------+----------------+-------------------+-----------------+-----------------------------+-----------------+
# only showing top 10 rows

# %%
import datetime
import pyspark.sql.functions as F
from pyspark.sql.window import Window
 
def input_event_paths(date, depth):
	dt = datetime.datetime.strptime(date, '%Y-%m-%d')
	return [f"/user/msdelendik/data/events/date={(dt-datetime.timedelta(days=x)).strftime('%Y-%m-%d')}" for x in range(depth)]

def calculate_user_interests(date, depth, spark):
		message_paths = input_event_paths(date, depth)
		tag_tops = spark.read\
    .option("basePath", "/user/msdelendik/data/events")\
    .parquet(*message_paths)\
    .where("event_type = 'message'")\
		.where("event.message_channel_to is not null")\
		.select(F.col("event.message_id").alias("message_id"),
		        F.col("event.message_from").alias("user_id"),
		        F.explode(F.col("event.tags")).alias("tag"))\
		.groupBy("user_id", "tag")\
		.agg(F.count("*").alias("tag_count"))\
		.withColumn("rank", F.row_number().over(Window.partitionBy("user_id")\
        .orderBy(F.desc("tag_count"), F.desc("tag"))))\
		.where("rank <= 3")\
		.groupBy("user_id")\
		.pivot("rank", [1, 2, 3])\
		.agg(F.first("tag"))\
		.withColumnRenamed("1", "tag_top_1")\
		.withColumnRenamed("2", "tag_top_2")\
		.withColumnRenamed("3", "tag_top_3")
 

		reaction_paths = input_event_paths(date, depth)
		reactions = spark.read\
    .option("basePath", "/user/msdelendik/data/events")\
    .parquet(*reaction_paths)\
    .where("event_type='reaction'")
 
		all_message_tags = spark.read.parquet("/user/msdelendik/data/events")\
		.where("event_type='message' and event.message_channel_to is not null")\
		.select(F.col("event.message_id").alias("message_id"),
		        F.col("event.message_from").alias("user_id"),
		        F.explode(F.col("event.tags")).alias("tag")
		)
 
		reaction_tags = reactions\
		.select(F.col("event.reaction_from").alias("user_id"), 
		        F.col("event.message_id").alias("message_id"), 
		        F.col("event.reaction_type").alias("reaction_type")
		).join(all_message_tags.select("message_id", "tag"), "message_id")
 
		reaction_tops = reaction_tags\
		.groupBy("user_id", "tag", "reaction_type")\
		.agg(F.count("*").alias("tag_count"))\
		.withColumn("rank", F.row_number().over(Window.partitionBy("user_id", "reaction_type")\
        .orderBy(F.desc("tag_count"), F.desc("tag"))))\
		.where("rank <= 3")\
		.groupBy("user_id", "reaction_type")\
		.pivot("rank", [1, 2, 3])\
		.agg(F.first("tag"))\
		.cache()
 
		like_tops = reaction_tops\
		.where("reaction_type = 'like'")\
		.drop("reaction_type")\
		.withColumnRenamed("1", "like_tag_top_1")\
		.withColumnRenamed("2", "like_tag_top_2")\
		.withColumnRenamed("3", "like_tag_top_3")
 
		dislike_tops = reaction_tops\
		.where("reaction_type = 'dislike'")\
		.drop("reaction_type")\
		.withColumnRenamed("1", "dislike_tag_top_1")\
		.withColumnRenamed("2", "dislike_tag_top_2")\
		.withColumnRenamed("3", "dislike_tag_top_3")
 
		result = like_tops\
		.join(dislike_tops, "user_id", "full_outer").join(tag_tops, "user_id", "full_outer")
		return result

calculate_user_interests('2022-04-04', 1, spark).write.parquet('/user/msdelendik/data/tmp/user_interests_04_04_1')
# Out:
# 2023-05-07 15:33:27,715 WARN execution.CacheManager: Asked to cache already cached data.

# %%
# !hdfs dfs -ls "/user/msdelendik/data/analytics"
# Out:
# Found 2 items
# drwxr-xr-x   - msdelendik msdelendik          0 2023-05-07 10:58 /user/msdelendik/data/analytics/candidates_d7_pyspark
# drwxr-xr-x   - msdelendik msdelendik          0 2023-05-07 11:01 /user/msdelendik/data/analytics/candidates_d84_pyspark
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_172 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_94 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_155 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_7 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_66 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_90 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_151 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_75 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_3 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_51 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_164 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_130 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_101 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_36 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_178 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_130 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_8 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_105 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_61 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_186 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_122 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_189 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_123 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_135 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_14 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_90 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_93 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_85 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_138 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_159 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_163 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_135 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_170 !
# 2023-05-07 15:44:10,906 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_160 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_30 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_72 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_118 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_145 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_157 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_146 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_139 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_181 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_102 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_167 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_143 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_126 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_41 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_25 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_111 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_79 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_196 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_74 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_113 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_83 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_195 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_180 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_192 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_183 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_56 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_149 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_196 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_45 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_116 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_107 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_85 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_174 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_98 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_155 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_169 !
# 2023-05-07 15:44:10,907 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_20 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_142 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_1 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_153 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_158 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_192 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_124 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_52 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_138 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_154 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_163 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_175 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_166 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_22 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_128 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_11 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_177 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_180 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_17 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_199 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_150 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_169 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_33 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_93 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_39 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_86 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_191 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_28 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_173 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_110 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_198 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_128 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_160 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_114 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_158 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_186 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_80 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_117 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_123 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_104 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_172 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_190 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_70 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_87 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_140 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_101 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_147 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_5 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_96 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_80 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_134 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_150 !
# 2023-05-07 15:44:10,946 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_48 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_76 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_98 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_185 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_167 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_195 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_154 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_108 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_119 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_145 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_64 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_73 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_134 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_181 !
# 2023-05-07 15:44:10,947 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_1 !
# 2023-05-07 15:46:03,401 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_157 !
# 2023-05-07 15:46:03,401 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_158 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_0 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_37 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_68 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_135 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_152 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_109 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_176 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_194 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_79 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_106 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_112 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_170 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_106 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_26 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_44 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_48 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_166 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_170 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_104 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_152 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_54 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_152 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_23 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_16 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_88 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_144 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_166 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_96 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_181 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_73 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_119 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_99 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_75 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_29 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_14 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_173 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_183 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_113 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_81 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_137 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_130 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_12 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_6 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_164 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_173 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_67 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_109 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_129 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_57 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_189 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_161 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_187 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_50 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_92 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_199 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_156 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_143 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_137 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_191 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_9 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_193 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_197 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_140 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_146 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_71 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_127 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_84 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_193 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_4 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_190 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_99 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_148 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_110 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_62 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_161 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_88 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_126 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_21 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_35 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_64 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_92 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_45 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_188 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_25 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_115 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_95 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_129 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_94 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_113 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_21 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_40 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_172 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_34 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_155 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_15 !
# 2023-05-07 15:46:03,402 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_47 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_46 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_141 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_84 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_198 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_18 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_29 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_197 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_194 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_68 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_41 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_186 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_77 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_77 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_9 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_168 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_168 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_184 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_54 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_122 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_2 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_176 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_177 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_179 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_43 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_24 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_56 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_116 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_183 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_12 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_36 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_120 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_164 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_149 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_109 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_117 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_31 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_52 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_39 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_59 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_32 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_27 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_7 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_66 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_180 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_141 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_19 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_138 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_230_119 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_102 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_133 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_49 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_63 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_60 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_273_161 !
# 2023-05-07 15:46:03,403 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_180_47 !

# %%
# !/usr/lib/spark/bin/spark-submit --master yarn --deploy-mode cluster /lessons/client_port.py 2022-05-04 5 /user/msdelendik/data/events /user/msdelendik/analytics/user_interests_d5

# %%
def main():

    conf = SparkConf().setAppName(f"Learning Dataframes-{date}")
    sc = SparkContext(conf=conf)
    sql = SQLContext(sc)

    date = sys.argv[1]
    days_count = int(sys.argv[2])
    event_base_path = sys.argv[3]
    output_base_path = sys.argv[4]

    # Здесь будет основная часть кода. Тело функции.
    tab = calculate_user_interests(date, days_count, sql)
    tab.write.parquet(output_base_path)
    
if __name__ == "__main__":
        main()
